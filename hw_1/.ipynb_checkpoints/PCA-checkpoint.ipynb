# %% [markdown]
# # Домашнее задание 1
# ## Бурмашев Григорий, Прокопова Полина, БПМИ-208

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.linalg import eig

# %%
df = pd.read_csv('diamonds_1000.csv')

# %%
numeric = ['price', 'carat', 'x', 'y', 'z']
df1 = df[numeric]

# %% [markdown]
# ### Z-scoring

# %%
Xz = (df1 - df1.mean()) / df1.std()

# %%
plt.hist(Xz['carat'])
plt.show()

# %% [markdown]
# #### Код прошлый год

# %%
uz, sz, vhz = np.linalg.svd(Xz)

uz_x = -uz[:, 0]
uz_y = uz[:, 1]
plt.figure(figsize=(10, 5))
plt.scatter(uz_x, uz_y)
plt.scatter(uz_x[Xz.iloc[:, 0].values < 0], uz_y[Xz.iloc[:, 0].values < 0])
plt.title('Визуализация путем Z-scoring')
plt.show()

print(vhz[0], vhz[1])
# Out:
# [0.21077771 0.49504176 0.49168541 0.49143776 0.47669781] [ 0.977101   -0.11720388 -0.09393896 -0.08919752 -0.12147496]

# %% [markdown]
# ####  Код с семинара

# %%
plt.hist(Xz['carat'])
plt.show()

# %%
z, mu, c = np.linalg.svd(Xz, full_matrices = False)

c = -c
z = -z 
z1 = np.sqrt(mu[0]) * z[:, 0]
z2 = np.sqrt(mu[1]) * z[:, 1]

# %%
mask = Xz['carat'] > Xz['carat'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(z1, z2, alpha=0.4, color='g')
plt.scatter(z1[mask], z2[mask], alpha=1, color='b', marker='d')
plt.title('Визуализация путем Z-scoring')
plt.show()

# %% [markdown]
# ### Нормирование с размахом

# %%
plt.scatter(z1, z2)

# %%
# Нормирование с размахом
Xr = (df1 - df1.mean()) / (df1.max() - df1.min())

# %%
plt.hist(Xr['carat'])
plt.show()

# %% [markdown]
# #### Код прошлый год

# %%
uz, sz, vhz = np.linalg.svd(Xr)

uz_x = -uz[:, 0]
uz_y = uz[:, 1] 
plt.figure(figsize=(10, 5))
plt.scatter(uz_x, uz_y)
plt.scatter(uz_x[Xr.iloc[:, 0].values < 0], uz_y[Xr.iloc[:, 0].values < 0])
plt.title('Визуализация путем стандартизации размахом')
plt.show()
print(vhz[0], vhz[1])
# Out:
# [0.34102356 0.45678412 0.49633969 0.46703328 0.45888782] [ 0.93984236 -0.17346552 -0.17143013 -0.15768869 -0.17986673]

# %% [markdown]
# ####  Код с семинара

# %%
z, mu, c = np.linalg.svd(Xr, full_matrices = False)

c = -c
z = -z 
z1 = np.sqrt(mu[0]) * z[:, 0]
z2 = np.sqrt(mu[1]) * z[:, 1]

# %%
plt.scatter(z1, z2)

# %%
mask = Xr['carat'] > Xr['carat'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(z1, z2, alpha=0.4, color='g')
plt.scatter(z1[mask], z2[mask], alpha=1, color='b', marker='d')
plt.title('Визуализация путем стандартизации размахом')
plt.show()

# %% [markdown]
# ### PCA

# %% [markdown]
# #### Z score

# %%
cov = np.dot(Xz.T, Xz) / (Xz.shape[0]-1)
eig_val, eig_vec = eig(cov)

# %%
z1_ = np.dot(Xz, eig_vec[:, 0]) / np.sqrt(Xz.shape[0] * eig_val[0])
cov = cov - eig_val[0] * eig_vec[:, 0].reshape((5, 1)) * eig_vec[:, 0]
eig_val, eig_vec = eig(cov)
z2_ = np.dot(Xz, -eig_vec[:, 0]) / np.sqrt(Xz.shape[0] * eig_val[0])

# %%
plt.scatter(-z1_, -z2_, alpha=0.4, color='g')
plt.scatter(-z1_[mask], -z2_[mask], alpha=1, color='b', marker='d')
plt.xlim(-1.0, 0.4)
plt.ylim(-0.4, 1.0)
# Out:
# (-0.4, 1.0)

# %%
mask = Xz['carat'] > Xz['carat'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(z1, z2, alpha=0.4, color='g')
plt.scatter(z1[mask], z2[mask], alpha=1, color='b', marker='d')

# %% [markdown]
# #### Размах

# %%
cov = np.dot(Xr.T, Xz) / (Xr.shape[0]-1)
eig_val, eig_vec = eig(cov)

# %%
z1_ = np.dot(Xr, eig_vec[:, 0]) / np.sqrt(Xr.shape[0] * eig_val[0])
cov = cov - eig_val[0] * eig_vec[:, 0].reshape((5, 1)) * eig_vec[:, 0]
eig_val, eig_vec = eig(cov)
z2_ = np.dot(Xr, -eig_vec[:, 0]) / np.sqrt(Xr.shape[0] * eig_val[0])

# %%
plt.scatter(z1_, z2_, alpha=0.4, color='g')
plt.scatter(z1_[mask], z2_[mask], alpha=1, color='b', marker='d')
plt.xlim(-1.0, 0.4)
plt.ylim(-0.4, 1.0)
# Out:
# (-0.4, 1.0)

# %%
mask = Xr['carat'] > Xr['carat'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(z1, z2, alpha=0.4, color='g')
plt.scatter(z1[mask], z2[mask], alpha=1, color='b', marker='d')
